# %% [markdown]
# <div style="direction:rtl; text-align:right">
#
# # المشروع السادس: هل تستطيع تصنيف النصوص؟

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# أهلاً بكم في المشروع السادس من علم البيانات. في هذا المشروع، سنقوم معاً بالنظر إلى بيانات فريدة من نوعها وهي مجموعة من النصوص المصنفة إلى مجالات مختلفة. سنقوم بنمذجة هذه البيانات لتوقع تصنيف النصوص بناء على الكلمات الواردة. تستطيع قراءة المزيد عن البيانات من خلال موقع سايكت-ليرن:

# %% [markdown]
# - https://scikit-learn.org/0.19/datasets/twenty_newsgroups.html

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# ملاحظة: عليك تعديل الخانات التي يوجد فيها الكود أدناه قبل تسليم المشروع. جميع الخانات الأخرى يجب ان تبقى كما هي بدون أي
# تعديل.
#
# ```
# ############################
# # عليك تعديل هذه الخانة قبل تسليم المشروع
# # YOU HAVE TO EDIT THIS CELLL
# ############################
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <div style="direction:rtl; text-align:right">
#
# # قراءة البيانات

# %%
from sklearn.datasets import fetch_20newsgroups

# %%
newsgroups_data = fetch_20newsgroups(subset='train')

# %%
X = newsgroups_data['data']
y = newsgroups_data['target']

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# لاحظ أن X هنا عبارة عن قائمة بالنصوص، وليست جدول كما هو الحال مع الدروس الأخرى. أما y فهي كذلك قائمة بالتصنيفات المختلفة. لمعرفة معنى التصنيفات نستطيع طباعة target_names:

# %%
for i, k in enumerate(newsgroups_data['target_names']):
    print(i, '\t->\t', k)
# Out:
# 0 	->	 alt.atheism
# 1 	->	 comp.graphics
# 2 	->	 comp.os.ms-windows.misc
# 3 	->	 comp.sys.ibm.pc.hardware
# 4 	->	 comp.sys.mac.hardware
# 5 	->	 comp.windows.x
# 6 	->	 misc.forsale
# 7 	->	 rec.autos
# 8 	->	 rec.motorcycles
# 9 	->	 rec.sport.baseball
# 10 	->	 rec.sport.hockey
# 11 	->	 sci.crypt
# 12 	->	 sci.electronics
# 13 	->	 sci.med
# 14 	->	 sci.space
# 15 	->	 soc.religion.christian
# 16 	->	 talk.politics.guns
# 17 	->	 talk.politics.mideast
# 18 	->	 talk.politics.misc
# 19 	->	 talk.religion.misc

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# وهنا سنقوم بطباعة أول قيمة من X

# %%
print(X[0])
# Out:
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----

# %%
for k, v in newsgroups_data.items():
    print(k)
# Out:
# data
# filenames
# target_names
# target
# DESCR

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# لنقم أولاً بعرض كم عدد النصوص لكل صنف ؟ قد تحتاج لاستخدام باندا للقيام بالمهمة!

# %%
############################
# عليك تعديل هذه الخانة قبل تسليم المشروع
# YOU HAVE TO EDIT THIS CELLL
############################

df = pd.DataFrame([newsgroups_data.data, newsgroups_data.target.tolist()]).T
df.columns=['text','target']
df['target'].value_counts()
# Out:
# 10    600
# 15    599
# 8     598
# 9     597
# 11    595
# 13    594
# 7     594
# 14    593
# 5     593
# 12    591
# 2     591
# 3     590
# 6     585
# 1     584
# 4     578
# 17    564
# 16    546
# 0     480
# 18    465
# 19    377
# Name: target, dtype: int64

# %%
df['number_of_words']=df['text'].apply(lambda x: len(x.split(' ')))
df.head()
# Out:
#                                                 text target  number_of_words
# 0  From: lerxst@wam.umd.edu (where's my thing)\nS...      7              114
# 1  From: guykuo@carson.u.washington.edu (Guy Kuo)...      4              107
# 2  From: twillis@ec.ecn.purdue.edu (Thomas E Will...      4              320
# 3  From: jgreen@amber (Joe Green)\nSubject: Re: W...      1               95
# 4  From: jcm@head-cfa.harvard.edu (Jonathan McDow...     14              159

# %%
num_to_cat ={}
for i, k in enumerate(newsgroups_data['target_names']):
    num_to_cat[i]=k

# %%
df2 = pd.DataFrame()
df2 = df2.assign(text=newsgroups_data['data']).assign(target=newsgroups_data['target'])
df2['category'] = df2['target']
df2['category'].replace(num_to_cat, inplace=True)
df2.head()
# Out:
#                                                 text  target  \
# 0  From: lerxst@wam.umd.edu (where's my thing)\nS...       7
# 1  From: guykuo@carson.u.washington.edu (Guy Kuo)...       4
# 2  From: twillis@ec.ecn.purdue.edu (Thomas E Will...       4
# 3  From: jgreen@amber (Joe Green)\nSubject: Re: W...       1
# 4  From: jcm@head-cfa.harvard.edu (Jonathan McDow...      14
#
#                 category
# 0              rec.autos
# 1  comp.sys.mac.hardware
# 2  comp.sys.mac.hardware
# 3          comp.graphics
# 4              sci.space

# %%
df2['category'].value_counts()
# Out:
# rec.sport.hockey            600
# soc.religion.christian      599
# rec.motorcycles             598
# rec.sport.baseball          597
# sci.crypt                   595
# sci.med                     594
# rec.autos                   594
# sci.space                   593
# comp.windows.x              593
# sci.electronics             591
# comp.os.ms-windows.misc     591
# comp.sys.ibm.pc.hardware    590
# misc.forsale                585
# comp.graphics               584
# comp.sys.mac.hardware       578
# talk.politics.mideast       564
# talk.politics.guns          546
# alt.atheism                 480
# talk.politics.misc          465
# talk.religion.misc          377
# Name: category, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11314 entries, 0 to 11313
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      11314 non-null  object
#  1   target    11314 non-null  int32
#  2   category  11314 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 221.1+ KB

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# نرى أن لدينا توازن في توزيع النصوص بين الأصناف المختلفة

# %% [markdown]
# <div style="direction:rtl; text-align:right">
#
# # تجهيز البيانات

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# ماذا نعمل عادة مع البيانات النصية؟ في هذه الحالة، سيكون أمامنا الكثير لنعمله حتى نقوم بتنظيف هذه البيانات وتهيئتها للتحليل. لذلك سنقوم بكتابة بعض الأوامر التي تساعدنا على ذلك.

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# المهمة الأولى: تنظيف النص

# %%
import re

# %%
############################
# عليك تعديل هذه الخانة قبل تسليم المشروع
# YOU HAVE TO EDIT THIS CELLL
############################


# HINT: figure out how to: delete special charachters, delete numbers, delete email addresses
#          if you dont know, use google!


def clean_text(text):
    #remove numbers
    text = re.sub('[0-9]+', ' ', text)
    text = re.sub(r'[A-Z]', '', text)
    # remove e-mail
    email =  r'\S*@\S*\s?' 
    text = re.sub(email, ' ', text)
    text = text.replace('{html}'," ") 
    cleanr = re.compile('<.*?>')
    text = re.sub(cleanr, ' ', text)
    text = re.sub(r'http\S+', '',text)
       #remove special char
    text = re.sub(r'\d+', ' ', text)
    text = re.sub(r"[^a-zA-Z0-9]+", ' ', text)
    text = re.sub(r'\s+', ' ', text)
    
    text = re.sub('  +', ' ', text)
    return text

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# حسنا، سنقوم الآن برؤية أثر هذه التعديلات على العنصر الأول في قائمة النصوص

# %%
X[10]
# Out:
# 'From: irwin@cmptrc.lonestar.org (Irwin Arnstein)\nSubject: Re: Recommendation on Duc\nSummary: What\'s it worth?\nDistribution: usa\nExpires: Sat, 1 May 1993 05:00:00 GMT\nOrganization: CompuTrac Inc., Richardson TX\nKeywords: Ducati, GTS, How much? \nLines: 13\n\nI have a line on a Ducati 900GTS 1978 model with 17k on the clock.  Runs\nvery well, paint is the bronze/brown/orange faded out, leaks a bit of oil\nand pops out of 1st with hard accel.  The shop will fix trans and oil \nleak.  They sold the bike to the 1 and only owner.  They want $3495, and\nI am thinking more like $3K.  Any opinions out there?  Please email me.\nThanks.  It would be a nice stable mate to the Beemer.  Then I\'ll get\na jap bike and call myself Axis Motors!\n\n-- \n-----------------------------------------------------------------------\n"Tuba" (Irwin)      "I honk therefore I am"     CompuTrac-Richardson,Tx\nirwin@cmptrc.lonestar.org    DoD #0826          (R75/6)\n-----------------------------------------------------------------------\n'

# %%
print(clean_text(X[10]))
# Out:
# rom rwin rnstein ubject e ecommendation on uc ummary hat s it worth istribution usa xpires at ay rganization ompurac nc ichardson eywords ucati ow much ines have a line on a ucati model with k on the clock uns very well paint is the bronze brown orange faded out leaks a bit of oil and pops out of st with hard accel he shop will fix trans and oil leak hey sold the bike to the and only owner hey want and am thinking more like ny opinions out there lease email me hanks t would be a nice stable mate to the eemer hen ll get a jap bike and call myself xis otors uba rwin honk therefore am ompurac ichardson x o

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# سنقوم الآن بتنفيذ ذات الأمر على باقي النصوص في X:

# %% [markdown]
# # Another Method

# %%
############################
# عليك تعديل هذه الخانة قبل تسليم المشروع
# YOU HAVE TO EDIT THIS CELLL
############################

X=list(map(clean_text, X))

# %% [markdown]
# Another method

# %%
"""
X2=[]
for tx in X:
    X2.append(clean_text(tx))
X=X2
"""
# Out:
# '\nX2=[]\nfor tx in X:\n    X2.append(clean_text(tx))\nX=X2\n'

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# الآن سنقوم باستخدام Td-IDF لتحويل الكلمات إلى مصفوفة ضخمة حتى نستخدمها في النمذجة. في الخانة التالية، ستقوم باستخدام TfidfVectorizer لتحويل النص.

# %%
############################
# عليك تعديل هذه الخانة قبل تسليم المشروع
# YOU HAVE TO EDIT THIS CELLL
############################
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
vec = TfidfVectorizer(analyzer='word', stop_words=stopwords.words('english'), ngram_range=(1, 2), min_df=2, max_df=0.5, max_features=30000)

trn_term_doc = vec.fit_transform(X)

# %%
trn_term_doc
# Out:
# <11314x30000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1289848 stored elements in Compressed Sparse Row format>

# %%
trn_term_doc.shape
# Out:
# (11314, 30000)

# %%
' | '.join(vec.get_feature_names())
# Out:
# 'aa | aa ark | aa teve | aab | aalke | aalke et | aalke ubject | aalke writes | aalliere | aan | aapanen | aaron | aas | aas ndrew | ab | ab arvard | ab aryland | ab atonia | ab elos | ab ines | ab mix | ab ndi | abak | abak ehari | abal | abal ines | abandon | abandoned | abaracci | abb | abbath | abbath dmissions | abbath rganization | abbi | abbit | abbreviation | abe | aber | aberhagen | abide | abiding | abiding citizens | abil | abilities | ability | ability federal | abin | abin rawer | abinet | able | able come | able find | able get | able handle | able help | able make | able run | able save | able see | able support | able tell | able use | aboard | abolish | abolished | abomination | abor | aboratories | aboratories ines | aboratory | aboratory asadena | aboratory ines | aboratory istribution | aboratory nc | aboratory ucson | abort | abortion | abortions | abre | abres | abretooth | abri | abri tan | abriel | abroad | abs | abs ines | abs olmdel | absence | absent | absolute | absolute certainty | absolute morality | absolute truth | absolutely | absolutely certain | absolutely nothing | absolutes | absorb | absorbed | absorption | abstinence | abstract | abstraction | abstracts | absurd | absurd whoever | absurdities | absurdities ertrand | absurdity | abundant | abuse | abused | abuses | abusing | abusive | aby | aby ike | abylon | ac | ac acker | ac indows | ac know | ac lus | ac nz | ac rganization | ac si | ac uadra | ac uk | ac version | ac za | acad | acad alaska | academia | academic | academic omputer | academics | acae | accelerate | accelerate development | accelerated | accelerating | acceleration | accelerations | accelerator | accelerators | accept | accept specific | accept word | acceptable | acceptance | acceptance wiretap | accepted | accepting | accepts | access | access confidential | access content | access data | access digex | access encryption | access information | access nix | access powerful | access system | access time | accessed | accesses | accessible | accessing | accessories | accessory | accident | accidental | accidental deaths | accidentally | accidently | accidents | acco | accommodate | accomodate | accompanied | accompanying | accomplish | accomplished | accord | accordance | according | accordingly | account | accountability | accountable | accounted | accounting | accounts | accumulate | accumulated | accuracy | accuracy information | accurate | accurately | accusation | accusations | accuse | accused | accusing | accustomed | acd | acd com | ace | ace uunet | acean | acedonian | acedonians | aceek | ach | achbereich | achbereich nformatik | ache | achel | achieve | achieved | achievement | achieving | achine | achines | achines ines | achines orp | achines orporation | achman | achman echnology | achs | aci | acial | acid | acidophilous | acids | acific | acific omputer | acilities | acility | acility ines | acing | acintosh | acintosh elease | acism | ack | ack chmidling | ack orris | ackage | ackard | ackard ewsreader | ackard ines | ackard oise | ackard ompany | ackard ort | acker | acker eluxe | acket | ackground | ackie | acking | acking oresh | acknowledge | acknowledged | acknowledgement | ackos | ackson | ackson awk | ackson ubject | ackup | aclus | acm | acne | acnnis | acns | acns nwu | acnteresteds | acnteresteds ashville | aco | aco needed | aco oday | acob | acobs | aconald | acorld | acpub | acpub duke | acquaintance | acquarie | acquarie niversity | acques | acquire | acquired | acquiring | acquisition | acramento | acro | acronym | acronyms | across | across country | across street | acs | acs acs | acs muohio | acs oakland | acs ohio | acs ucalgary | acser | acsu | acsu buffalo | act | act front | act heet | act like | act quickly | acted | acting | action | actions | actions taken | activated | active | actively | activist | activists | activities | activities moon | activities net | activity | actor | actory | actory ew | acts | actual | actually | actua ...

# %% [markdown]
# <div style="direction:rtl; text-align:right">
#
# # نمذجة البيانات

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# سنقوم الآن بنمذجة البيانات. لنبدأ بالانحدار اللوجستي. في الخانة أدناه، قم باستيراد كلاً من مكتبة الانحدار اللوجستي، وأمر cross_val_score ثم استخدمهم في تدريب النموذج والتحقق من صحته.

# %%
############################
# عليك تعديل هذه الخانة قبل تسليم المشروع
# YOU HAVE TO EDIT THIS CELLL
############################

# HINT: You should use `train_data` as your input
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
model = LogisticRegression()
scores = cross_val_score(model, trn_term_doc, y, scoring='accuracy')

# %%
avg_score = scores.mean()

# %%
print('Average accuracy is: ', avg_score)
# Out:
# Average accuracy is:  0.8847448654067882

# %% [markdown]
# <div style="direction:rtl; text-align:right">
# لا تحتاج في هذا المشروع إلى تسليم أي ملف إلى كاقل. ولكن تأكد من صحة الإجابات ثم قم بتسليم المشروع في الموقع.
